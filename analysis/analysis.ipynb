# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import os
import json
s = json.load(open(os.getenv('PUI2015')+'/plotstyle.json'))
plt.rcParams.update(s)
# %matplotlib inline
# Out:
# /Users/eliseowang/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:855: UserWarning: svg.embed_char_paths is deprecated and replaced with svg.fonttype; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
# have a quick look at the data
path = '/Users/eliseowang/Documents/AppliedDataScience/project/sh_test.csv'
data = pd.read_csv(path)
print data.head()
data.describe()
# Out:
#              genCategory             category  \
# 0     Travel & Transport                Hotel
# 1                    NaN  Szechuan Restaurant
# 2  Outdoors & Recreation          Golf Course
# 3         Shop & Service    Electronics Store
# 4                   Food  Japanese Restaurant
#
#                                  name         lon        lat  checkIns  tips  \
# 0  上海天禧嘉福酒店 Skyfortune Boutique Hotel  121.390842  31.183345       217     3
# 1                               四川香天下  121.392031  31.183549         9     0
# 2         Hongqiao Golf Driving range  121.386053  31.187153       169     3
# 3                             蘇寧電器吳中路  121.389871  31.182312        10     0
# 4                              龙之介炉端烧  121.387928  31.182557       120     1
#
#    users    createdAt         tileID                        ID  \
# 0    136  2011.09.21   0_00_00_00_10  4e79a8e88877bac8d1cbbfbd
# 1      3  2015.08.01   0_00_00_00_10  55bcad8a498e6bfc6d59ee71
# 2     82  2012.04.02   0_00_00_00_10  4f79acbfe4b0795c3a0102d6
# 3      6  2013.01.06   0_00_00_00_10  50e91cfae4b09c384603f0fa
# 4     51  2010.08.20   0_00_00_00_10  4c6e686c65eda093bd4251d0
#
#             query                  time verified  price  rating tags  \
# 0  China_Shanghai  2015.11.08 22:54:55     False     -1      -1  NaN
# 1  China_Shanghai  2015.11.08 22:54:55     False     -1      -1  NaN
# 2  China_Shanghai  2015.11.08 22:54:56     False     -1      -1  NaN
# 3  China_Shanghai  2015.11.08 22:54:56     False     -1      -1  NaN
# 4  China_Shanghai  2015.11.08 22:54:56     False     -1      -1  NaN
#
#    photoCount description
# 0          23         NaN
# 1           1         NaN
# 2          12         NaN
# 3           2         NaN
# 4           8         NaN
#                 lon           lat      checkIns          tips         users  \
# count  10075.000000  10075.000000  10075.000000  10075.000000  10075.000000
# mean     121.460175     31.227608    171.302333      2.006253     69.733499
# std        0.047124      0.036851    729.115512      8.403823    314.768264
# min      121.383820     31.170800      0.000000      0.000000      0.000000
# 25%      121.422460     31.199055      2.000000      0.000000      1.000000
# 50%      121.451998     31.224647      6.000000      0.000000      4.000000
# 75%      121.500624     31.249591     35.000000      0.000000     13.000000
# max      121.548538     31.316262  23272.000000    184.000000  10032.000000
#
#         verified         price        rating    photoCount
# count      10075  10075.000000  10075.000000  10075.000000
# mean   0.0179653     -0.995136     -0.177945     14.489330
# std     0.132832      0.132463      2.485988    114.298239
# min        False     -1.000000     -1.000000    -17.000000
# 25%            0     -1.000000     -1.000000      0.000000
# 50%            0     -1.000000     -1.000000      0.000000
# 75%            0     -1.000000     -1.000000      2.000000
# max         True      3.000000      9.500000   8195.000000

# %% [markdown]
# We are assuming the users of 4square are homogeneous group of people with similar behaviors. Foursquare users are considered sensors around the world, reflecting the data.

# %% [markdown]
# ## See what the unique categories are (in alphabetical order)

# %%
catValues = sorted(data['genCategory'].unique())
catValues
# Out:
# [nan,
#  'Arts & Entertainment',
#  'College & University',
#  'Event',
#  'Food',
#  'Nightlife Spot',
#  'Outdoors & Recreation',
#  'Professional & Other Places',
#  'Residence',
#  'Shop & Service',
#  'Travel & Transport']

# %% [markdown]
# ## Create a categorical value for each category string (not necessary but just in case you need it in your column)

# %%
# create a dictionary of string-int pair.
unique = {catValues[i]:i for i in range(len(catValues))}
# set the numerical value of NaNs to np.nan
unique[np.nan] = np.nan
unique
# Out:
# {nan: nan,
#  'Arts & Entertainment': 1,
#  'College & University': 2,
#  'Event': 3,
#  'Food': 4,
#  'Nightlife Spot': 5,
#  'Outdoors & Recreation': 6,
#  'Professional & Other Places': 7,
#  'Residence': 8,
#  'Shop & Service': 9,
#  'Travel & Transport': 10}

# %%
# transform the dic into a dataframe
cateValues = pd.DataFrame(unique, 
                      index=[1]).T.reset_index().rename(columns={'index':'genCategory',
                                                                 1:'CateValue'})
cateValues
# Out:
#                     genCategory  CateValue
# 0                           NaN        NaN
# 1          Arts & Entertainment          1
# 2          College & University          2
# 3                         Event          3
# 4                          Food          4
# 5                Nightlife Spot          5
# 6         Outdoors & Recreation          6
# 7   Professional & Other Places          7
# 8                     Residence          8
# 9                Shop & Service          9
# 10           Travel & Transport         10

# %%
cateValues.T
colors = {}
for i in cateValues.T:
    colors[cateValues.T[i].ix['genCategory']] = cateValues.T[i].ix['CateValue']

# %%
# give pair the genCategory of each row with the corresponding categorical value
data2 = data.merge(cateValues, how='left', on='genCategory')
print data2.shape
data2.head()
# Out:
# (10075, 20)
#              genCategory             category  \
# 0     Travel & Transport                Hotel
# 1                    NaN  Szechuan Restaurant
# 2  Outdoors & Recreation          Golf Course
# 3         Shop & Service    Electronics Store
# 4                   Food  Japanese Restaurant
#
#                                  name         lon        lat  checkIns  tips  \
# 0  上海天禧嘉福酒店 Skyfortune Boutique Hotel  121.390842  31.183345       217     3
# 1                               四川香天下  121.392031  31.183549         9     0
# 2         Hongqiao Golf Driving range  121.386053  31.187153       169     3
# 3                             蘇寧電器吳中路  121.389871  31.182312        10     0
# 4                              龙之介炉端烧  121.387928  31.182557       120     1
#
#    users    createdAt         tileID                        ID  \
# 0    136  2011.09.21   0_00_00_00_10  4e79a8e88877bac8d1cbbfbd
# 1      3  2015.08.01   0_00_00_00_10  55bcad8a498e6bfc6d59ee71
# 2     82  2012.04.02   0_00_00_00_10  4f79acbfe4b0795c3a0102d6
# 3      6  2013.01.06   0_00_00_00_10  50e91cfae4b09c384603f0fa
# 4     51  2010.08.20   0_00_00_00_10  4c6e686c65eda093bd4251d0
#
#             query                  time verified  price  rating tags  \
# 0  China_Shanghai  2015.11.08 22:54:55     False     -1      -1  NaN
# 1  China_Shanghai  2015.11.08 22:54:55     False     -1      -1  NaN
# 2  China_Shanghai  2015.11.08 22:54:56     False     -1      -1  NaN
# 3  China_Shanghai  2015.11.08 22:54:56     False     -1      -1  NaN
# 4  China_Shanghai  2015.11.08 22:54:56     False     -1      -1  NaN
#
#    photoCount description  CateValue
# 0          23         NaN         10
# 1           1         NaN        NaN
# 2          12         NaN          6
# 3           2         NaN          9
# 4           8         NaN          4

# %% [markdown]
# ## Clean the data a little bit. Take checkIn No. larger than 10.

# %%
data3 = data2[(data2['users'] >= 100) &
              (data2['checkIns'] >= 100) &
              (data2['CateValue'] != np.nan)]

# %%
print data3.shape
data3.head()
# Out:
# (1075, 20)
#             genCategory             category  \
# 0    Travel & Transport                Hotel
# 91       Shop & Service                 Mall
# 92   Travel & Transport        Metro Station
# 94       Shop & Service                 Mall
# 100                Food  American Restaurant
#
#                                    name         lon        lat  checkIns  \
# 0    上海天禧嘉福酒店 Skyfortune Boutique Hotel  121.390842  31.183345       217
# 91                光启城 | Sunny Days City  121.423193  31.186215      1725
# 92       宜山路地铁站 | Yishan Rd. Metro Stn.  121.422658  31.188354      2652
# 94                      Carrefour | 家乐福  121.423305  31.186000       322
# 100                         Laya Burger  121.421776  31.183936       159
#
#      tips  users    createdAt         tileID                        ID  \
# 0       3    136  2011.09.21   0_00_00_00_10  4e79a8e88877bac8d1cbbfbd
# 91      4    515  2012.05.09   0_00_00_01_11  4fa9ebdbe4b0afe1f1cd2b04
# 92      5    601  2010.02.22   0_00_00_01_11  4b82498cf964a52016cf30e3
# 94      3    159  2012.08.13   0_00_00_01_11  5028928be4b004413ab8b0b1
# 100     6    107  2012.12.16   0_00_00_01_11  50cd5eebe4b03ff341662aac
#
#               query                  time verified  price  rating  \
# 0    China_Shanghai  2015.11.08 22:54:55     False     -1    -1.0
# 91   China_Shanghai  2015.11.08 22:55:50     False     -1     5.5
# 92   China_Shanghai  2015.11.08 22:55:50     False     -1    -1.0
# 94   China_Shanghai  2015.11.08 22:55:50     False     -1     5.4
# 100  China_Shanghai  2015.11.08 22:55:51     False     -1     5.5
#
#                                                   tags  photoCount  \
# 0                                                  NaN          23
# 91                                                 NaN          54
# 92   metro line 3;metro line 4;metro line 9;metro s...          47
# 94                                                 NaN          15
# 100                                                NaN          24
#
#     description  CateValue
# 0           NaN         10
# 91          NaN          9
# 92          NaN         10
# 94          NaN          9
# 100         NaN          4

# %% [markdown]
# ## Plot all the general categories on the same figure using different colors for each category.

# %%
# group the data by general category
groups = data3.groupby('genCategory')
# create a 10 * 10 figure
fig, ax = plt.subplots(figsize=(10,10))
# add 5% padding to the autoscaling
ax.margins(0.05)
# plot all the general categories
for name, group in groups:
    ax.plot(group.users, group.checkIns, marker='o',
            linestyle='', ms=6, alpha=.6, label=name)

ax.set_ylabel('User numbers', fontsize=15)
ax.set_xlabel('CheckIn numbers', fontsize=15)
ax.set_title('CheckIn number of each gen Category', fontsize=20)
ax.legend()

# %% [markdown]
# ## Plot at log scale

# %%
# group the data by general category
groups = data3.groupby('genCategory')
# create a 10 * 10 figure
fig, ax = plt.subplots(figsize=(10,10))
# add 5% padding to the autoscaling
ax.margins(0.05)
# plot all the general categories
for name, group in groups:
    ax.plot(np.log10(group.users), np.log10(group.checkIns), marker='o',
            linestyle='', ms=6, alpha=.6, label=name )

ax.set_ylabel('User numbers, log10 scale', fontsize=15)
ax.set_xlabel('CheckIn numbers, log10 scale', fontsize=15)
ax.set_title('CheckIn number of each gen Category, log10 scale', fontsize=20)
ax.grid(False)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ## plot each general category on a different figure

# %%
np.random.seed(2015)
# create a 10 * 10 figure
fig1  = plt.figure(figsize=(10,10))
for name, group in groups:
    group.plot(x = 'users', y = 'checkIns', 
               kind = 'scatter',color = np.random.rand(3),
               label = name, 
               title = 'checkIn number %s' %name,
               fontsize = 10)
# Out:
# /Users/eliseowang/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ## Plot each figure separately at log level

# %%
np.random.seed(2015)
# create a 10 * 10 figure
fig1= plt.figure(figsize=(10,10))
for name, group in groups:
    group.plot(x = 'users', y = 'checkIns',
               kind = 'scatter',color = np.random.rand(3),
               label = name, loglog = True,
               title = 'checkIn number of each category',
               fontsize = 10)

# %%
# run a linear regression (without intercept) for the data
lm = smf.ols(formula='Y ~ X - 1',
             data={'Y':data3.checkIns,
                   'X':data3.users}).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     6742.
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):               0.00
# Time:                        10:23:26   Log-Likelihood:                -8767.4
# No. Observations:                1075   AIC:                         1.754e+04
# Df Residuals:                    1074   BIC:                         1.754e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              2.1423      0.026     82.109      0.000         2.091     2.193
# ==============================================================================
# Omnibus:                      598.209   Durbin-Watson:                   1.717
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35500.252
# Skew:                           1.772   Prob(JB):                         0.00
# Kurtosis:                      30.929   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Plot the regression line for the whole dataset

# %%
# group the data by general category
groups = data3.groupby('genCategory')
# create a 10 * 10 figure
fig, ax = plt.subplots(figsize=(10,10))
# add 5% padding to the autoscaling
ax.margins(0.05)
# plot all the general categories
for name, group in groups:
    ax.plot(group.users, group.checkIns, marker='o',
            linestyle='', ms=6, alpha=.6, label=name)
plt.plot(data3.users, lm.predict(), color='r',
         lw=3, label='linear regression')
ax.set_xlabel('User numbers', fontsize = 15)
ax.set_ylabel('CheckIns numbers', fontsize = 15)
ax.set_title('CheckIn numbers', fontsize = 20)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., numpoints = 1)

# %% [markdown]
# ## Run and plot regression line for the whole dataset at log scale

# %%
lm1 = smf.ols(formula='Y ~ X - 1',
             data={'Y':np.log10(data3.checkIns),
                   'X':np.log10(data3.users)}).fit()
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 2.145e+05
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):               0.00
# Time:                        10:23:27   Log-Likelihood:                 159.06
# No. Observations:                1075   AIC:                            -316.1
# Df Residuals:                    1074   BIC:                            -311.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.1314      0.002    463.183      0.000         1.127     1.136
# ==============================================================================
# Omnibus:                      308.068   Durbin-Watson:                   1.679
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              893.845
# Skew:                           1.441   Prob(JB):                    8.02e-195
# Kurtosis:                       6.412   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# group the data by general category
groups = data3.groupby('genCategory')
# create a 10 * 10 figure
fig, ax = plt.subplots(figsize=(10,10))
# add 5% padding to the autoscaling
ax.margins(0.05)
# plot all the general categories
for name, group in groups:
    ax.plot(np.log10(group.users), np.log10(group.checkIns),
            marker='o',linestyle='', ms=6, 
            alpha=.6, label=name )
plt.plot(np.log10(data3.users), lm1.predict(), 
         color='r', lw=3, label='linear regression')
ax.set_xlabel('User numbers, log10 scale', fontsize = 15)
ax.set_ylabel('CheckIns numbers, log10 scale', fontsize = 15)
ax.set_title('CheckIn Numbers', fontsize = 20)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, 
          borderaxespad=0., numpoints = 1)

# %% [markdown]
# # run and plot linear regression for the whole dataset and for each category

# %%
# group the data by general category
groups = data3.groupby('genCategory')
# create a 10 * 10 figure
fig, ax = plt.subplots(figsize=(10,10))
# add 5% padding to the autoscaling
ax.margins(0.05)
# add a seed
np.random.seed(2015)
# run a linear regression for the whole dataset
lm = smf.ols(formula='Y ~ X',
             data={'Y':data3.checkIns,
                   'X':data3.users}).fit()
lm.summary()
# create an empty dictionary to hold the regression results
lmE = {}
for name, group in groups:
# run linear regression for each general category
    lmE['%s'%name[:3]] = smf.ols(formula='Y ~ X', 
                                 data={'Y':group.checkIns, 
                                       'X':group.users}).fit()
# scatter plot each general category in different colors
    ax.plot(group.users, group.checkIns,
            marker='o',linestyle='', ms=6, 
            alpha=.6, label=name)
# plot each regression line for each general category in corresponding color
    plt.plot(group.users, lmE['%s'%name[:3]].predict(),
             lw=2, label='lm %s' %name)
# plot the regression line for the whole dataset
plt.plot(data3.users, lm.predict(), color='r',
         lw=3, label='lr for the whole dataset')
ax.set_xlabel('User numbers, log10 scale', fontsize = 15)
ax.set_ylabel('CheckIns numbers, log10 scale', fontsize = 15)
ax.set_title('CheckIn Numbers', fontsize = 20)
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., numpoints = 1)

# %% [markdown]
# ## Run a linear regression for each category and plot them separately

# %%
np.random.seed(2015)
lmE = {}
# create a 10 * 10 figure
fig1= plt.figure(figsize=(10,10))
for name, group in groups:
    lmE['%s'%name[:3]] = smf.ols(formula='Y ~ X - 1', 
                                 data={'Y':group.checkIns, 
                                       'X':group.users}).fit()
    group.plot(x='users', y='checkIns', 
               kind='scatter',color=np.random.rand(3),
               label=name, title='checkIn number of %s'%name,
               fontsize=10)
    plt.plot(group.users, lmE['%s'%name[:3]].predict(),
             color='r', lw=2, label='linear regression')
    print '%s' %name
    print lmE['%s'%name[:3]].summary()
    print '\n'
# Out:
# Arts & Entertainment
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     960.1
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):           6.24e-33
# Time:                        10:23:28   Log-Likelihood:                -334.74
# No. Observations:                  48   AIC:                             671.5
# Df Residuals:                      47   BIC:                             673.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.7739      0.057     30.986      0.000         1.659     1.889
# ==============================================================================
# Omnibus:                       25.256   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.003
# Skew:                           1.332   Prob(JB):                     7.67e-15
# Kurtosis:                       8.041   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# College & University
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     633.1
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):           4.50e-11
# Time:                        10:23:28   Log-Likelihood:                -85.100
# No. Observations:                  12   AIC:                             172.2
# Df Residuals:                      11   BIC:                             172.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              4.4419      0.177     25.162      0.000         4.053     4.830
# ==============================================================================
# Omnibus:                       10.334   Durbin-Watson:                   1.373
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):                5.447
# Skew:                           1.450   Prob(JB):                       0.0657
# Kurtosis:                       4.578   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Food
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.909
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     4081.
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):          1.50e-215
# Time:                        10:23:28   Log-Likelihood:                -3002.6
# No. Observations:                 412   AIC:                             6007.
# Df Residuals:                     411   BIC:                             6011.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.9814      0.031     63.885      0.000         1.920     2.042
# ==============================================================================
# Omnibus:                      140.142   Durbin-Watson:                   1.785
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1022.992
# Skew:                           1.248   Prob(JB):                    7.24e-223
# Kurtosis:                      10.305   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Nightlife Spot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     2078.
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):           9.23e-77
# Time:                        10:23:28   Log-Likelihood:                -916.57
# No. Observations:                 119   AIC:                             1835.
# Df Residuals:                     118   BIC:                             1838.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              2.3335      0.051     45.582      0.000         2.232     2.435
# ==============================================================================
# Omnibus:                       26.072   Durbin-Watson:                   1.457
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              108.303
# Skew:                           0.591   Prob(JB):                     3.04e-24
# Kurtosis:                       7.522   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Outdoors & Recreation
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.897
# Method:                 Least Squares   F-statistic:                     473.1
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):           4.41e-28
# Time:                        10:23:28   Log-Likelihood:                -473.51
# No. Observations:                  54   AIC:                             949.0
# Df Residuals:                      53   BIC:                             951.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.8940      0.087     21.752      0.000         1.719     2.069
# ==============================================================================
# Omnibus:                       50.171   Durbin-Watson:                   1.686
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              587.116
# Skew:                           1.951   Prob(JB):                    3.23e-128
# Kurtosis:                      18.675   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Professional & Other Places
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     342.8
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):           7.81e-28
# Time:                        10:23:28   Log-Likelihood:                -549.98
# No. Observations:                  67   AIC:                             1102.
# Df Residuals:                      66   BIC:                             1104.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.7195      0.093     18.515      0.000         1.534     1.905
# ==============================================================================
# Omnibus:                       14.436   Durbin-Watson:                   1.360
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               60.183
# Skew:                          -0.114   Prob(JB):                     8.54e-14
# Kurtosis:                       7.637   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Residence
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.516
# Method:                 Least Squares   F-statistic:                     13.82
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):            0.00340
# Time:                        10:23:29   Log-Likelihood:                -100.74
# No. Observations:                  12   AIC:                             203.5
# Df Residuals:                      11   BIC:                             204.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              6.9680      1.875      3.717      0.003         2.842    11.094
# ==============================================================================
# Omnibus:                        3.932   Durbin-Watson:                   2.871
# Prob(Omnibus):                  0.140   Jarque-Bera (JB):                1.637
# Skew:                           0.884   Prob(JB):                        0.441
# Kurtosis:                       3.389   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Shop & Service
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     1098.
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):           5.67e-72
# Time:                        10:23:29   Log-Likelihood:                -1290.2
# No. Observations:                 155   AIC:                             2582.
# Df Residuals:                     154   BIC:                             2585.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              2.4499      0.074     33.139      0.000         2.304     2.596
# ==============================================================================
# Omnibus:                      131.659   Durbin-Watson:                   1.704
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2136.671
# Skew:                           2.920   Prob(JB):                         0.00
# Kurtosis:                      20.226   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Travel & Transport
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     890.2
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):           1.40e-66
# Time:                        10:23:29   Log-Likelihood:                -1328.2
# No. Observations:                 158   AIC:                             2658.
# Df Residuals:                     157   BIC:                             2661.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              2.6392      0.088     29.836      0.000         2.465     2.814
# ==============================================================================
# Omnibus:                      108.695   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1066.356
# Skew:                           2.362   Prob(JB):                    2.78e-232
# Kurtosis:                      14.818   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/eliseowang/anaconda/lib/python2.7/site-packages/scipy/stats/stats.py:1277: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))

# %%
np.random.seed(2015)
lmL = {}
# create a 10 * 10 figure
fig1= plt.figure(figsize = (10,10))
for name, group in groups:
    lmL['%s'%name[:3]] = smf.ols(formula='Y ~ X - 1', 
                                 data={'Y':np.log10(group.checkIns), 
                                       'X':np.log10(group.users)}).fit()
    group.plot(x='users', y='checkIns', loglog= True,
               kind='scatter', color=np.random.rand(3),
               label=name, title='checkIn number of %s'%name,
               fontsize=10)
    plt.plot(np.log10(group.users), lmL['%s'%name[:3]].predict(),
             color='r', lw=2, label='linear regression')
    print '%s' %name
    print lmL['%s'%name[:3]].summary()
    print '\n'
# Out:
# Arts & Entertainment
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 3.025e+04
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):           1.11e-67
# Time:                        10:23:31   Log-Likelihood:                 36.446
# No. Observations:                  48   AIC:                            -70.89
# Df Residuals:                      47   BIC:                            -69.02
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.0848      0.006    173.929      0.000         1.072     1.097
# ==============================================================================
# Omnibus:                        6.126   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                5.095
# Skew:                           0.764   Prob(JB):                       0.0783
# Kurtosis:                       3.464   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# College & University
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     7116.
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):           8.10e-17
# Time:                        10:23:31   Log-Likelihood:                 8.3222
# No. Observations:                  12   AIC:                            -14.64
# Df Residuals:                      11   BIC:                            -14.16
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.2365      0.015     84.356      0.000         1.204     1.269
# ==============================================================================
# Omnibus:                        0.217   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.897   Jarque-Bera (JB):                0.389
# Skew:                          -0.184   Prob(JB):                        0.823
# Kurtosis:                       2.198   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Food
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 1.685e+05
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):               0.00
# Time:                        10:23:31   Log-Likelihood:                 227.32
# No. Observations:                 412   AIC:                            -452.6
# Df Residuals:                     411   BIC:                            -448.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.1112      0.003    410.472      0.000         1.106     1.117
# ==============================================================================
# Omnibus:                       48.573   Durbin-Watson:                   1.766
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.254
# Skew:                           0.844   Prob(JB):                     6.76e-15
# Kurtosis:                       3.977   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Nightlife Spot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 5.436e+04
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):          4.67e-159
# Time:                        10:23:32   Log-Likelihood:                 63.745
# No. Observations:                 119   AIC:                            -125.5
# Df Residuals:                     118   BIC:                            -122.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.1233      0.005    233.154      0.000         1.114     1.133
# ==============================================================================
# Omnibus:                       14.654   Durbin-Watson:                   1.336
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.239
# Skew:                           0.667   Prob(JB):                     6.64e-05
# Kurtosis:                       4.449   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Outdoors & Recreation
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 1.613e+04
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):           1.55e-67
# Time:                        10:23:32   Log-Likelihood:                 16.377
# No. Observations:                  54   AIC:                            -30.75
# Df Residuals:                      53   BIC:                            -28.76
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.1192      0.009    127.011      0.000         1.102     1.137
# ==============================================================================
# Omnibus:                        0.199   Durbin-Watson:                   1.411
# Prob(Omnibus):                  0.905   Jarque-Bera (JB):                0.061
# Skew:                           0.081   Prob(JB):                        0.970
# Kurtosis:                       2.969   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Professional & Other Places
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     8095.
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):           8.91e-71
# Time:                        10:23:33   Log-Likelihood:                -6.7849
# No. Observations:                  67   AIC:                             15.57
# Df Residuals:                      66   BIC:                             17.77
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.1568      0.013     89.971      0.000         1.131     1.182
# ==============================================================================
# Omnibus:                        7.512   Durbin-Watson:                   1.694
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                2.760
# Skew:                           0.084   Prob(JB):                        0.252
# Kurtosis:                       2.020   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Residence
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.985
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     725.5
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):           2.15e-11
# Time:                        10:23:33   Log-Likelihood:                -5.2635
# No. Observations:                  12   AIC:                             12.53
# Df Residuals:                      11   BIC:                             13.01
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.3845      0.051     26.935      0.000         1.271     1.498
# ==============================================================================
# Omnibus:                        0.392   Durbin-Watson:                   3.035
# Prob(Omnibus):                  0.822   Jarque-Bera (JB):                0.478
# Skew:                           0.070   Prob(JB):                        0.787
# Kurtosis:                       2.032   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Shop & Service
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 1.928e+04
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):          1.06e-163
# Time:                        10:23:33   Log-Likelihood:                -17.683
# No. Observations:                 155   AIC:                             37.37
# Df Residuals:                     154   BIC:                             40.41
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.1650      0.008    138.861      0.000         1.148     1.182
# ==============================================================================
# Omnibus:                       35.427   Durbin-Watson:                   1.805
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               51.854
# Skew:                           1.251   Prob(JB):                     5.50e-12
# Kurtosis:                       4.328   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Travel & Transport
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 3.573e+04
# Date:                Fri, 13 Nov 2015   Prob (F-statistic):          4.14e-187
# Time:                        10:23:33   Log-Likelihood:                 26.994
# No. Observations:                 158   AIC:                            -51.99
# Df Residuals:                     157   BIC:                            -48.92
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# X              1.1537      0.006    189.032      0.000         1.142     1.166
# ==============================================================================
# Omnibus:                        9.463   Durbin-Watson:                   1.593
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               10.160
# Skew:                           0.615   Prob(JB):                      0.00622
# Kurtosis:                       2.821   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Remember to clean up the repeated data tmr

# %% [markdown]
# ## run a K-means clustering

# %%
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
import statsmodels.formula.api as smf
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# # Question about the clustering: is it right to apply clustering directly in the pandas dataframe?

# %%
train = data3[['users','checkIns']]
train.index = data3.CateValue
train.head(10)
# Out:
#            users  checkIns
# CateValue
# 10           136       217
# 9            515      1725
# 10           601      2652
# 9            159       322
# 4            107       159
# 9            106       185
# 10           975      1964
# 4            271       987
# 8            179       506
# 10           142       311

# %%
est_prob3=KMeans(n_clusters=10,n_init=100)
est_prob3.fit(train)
labels=est_prob3.labels_
plt.figure(figsize=(8,8))
plt.scatter(train.users,train.checkIns,s=40,c=labels.astype(np.float),lw=0)
plt.xlabel('users', fontsize = 15)
plt.ylabel('checkIns', fontsize = 15)
plt.grid()

# %%
# start with a list of empty silhouette values
s = [0]*10
# select the best k
for i in range(0,10):
    est=KMeans(n_clusters=i+2,n_init=100)
    est.fit(train)
    s[i]=silhouette_score(train, est.labels_)
    print('{0} clusters: {1}'.format(i+2,s[i]))
j=np.argmax(s) # select best k value (max avg silhouette value)    
est=KMeans(n_clusters=j+2,n_init=100)
est.fit(train)
labels=est.labels_
print('Best for {0} clusters: {1}\n'.format(j+2,silhouette_score(train, labels)))
# Out:
# 2 clusters: 0.839116267203
# 3 clusters: 0.671339002412
# 4 clusters: 0.621462435666
# 5 clusters: 0.589002619664
# 6 clusters: 0.559224876265
# 7 clusters: 0.521662229848
# 8 clusters: 0.512772262619
# 9 clusters: 0.515326233728
# 10 clusters: 0.500119003208
# 11 clusters: 0.486987770036
# Best for 2 clusters: 0.839116267203
# /Users/eliseowang/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
plt.figure()
plt.bar(range(2,12),s)
plt.xlabel('k')
plt.ylabel('S')
plt.title('Avg Silhouette vs k')

# %%
plt.figure(figsize=(8,8))
plt.scatter (train.users,train.checkIns,s=40,c=labels.astype(np.float),lw=0)

# %%
cluster1 = data3[(data3.users >= 2000) & (data3.checkIns >= 5000)]
cluster1.shape
# Out:
# (30, 20)

# %%
cluster1.describe()
# Out:
#               lon        lat      checkIns        tips        users  verified  \
# count   30.000000  30.000000     30.000000   30.000000     30.00000        30
# mean   121.464808  31.227145   9405.200000   68.266667   4113.30000       0.3
# std      0.024383   0.015999   3661.271886   41.683482   1969.31569  0.466092
# min    121.411822  31.180020   5204.000000   13.000000   2035.00000     False
# 25%    121.442310  31.220853   7215.750000   39.250000   2442.25000         0
# 50%    121.469361  31.234236   8891.000000   61.000000   3537.50000         0
# 75%    121.484709  31.238490  10203.750000   87.250000   4793.50000         1
# max    121.503103  31.251112  23272.000000  184.000000  10032.00000      True
#
#            price     rating   photoCount  CateValue
# count  30.000000  30.000000    30.000000   30.00000
# mean   -0.733333   6.900000  1152.400000    8.00000
# std     1.014833   2.825134  1564.101077    1.83829
# min    -1.000000  -1.000000   207.000000    5.00000
# 25%    -1.000000   6.775000   381.500000    6.00000
# 50%    -1.000000   7.900000   678.000000    9.00000
# 75%    -1.000000   8.300000  1190.250000    9.00000
# max     3.000000   9.500000  8195.000000   10.00000

# %%
cluster1
# Out:
#                       genCategory                category  \
# 187                Shop & Service  Furniture / Home Store
# 287                Shop & Service                    Mall
# 288                Shop & Service                    Mall
# 539                Shop & Service                    Mall
# 718         Outdoors & Recreation            Neighborhood
# 767         Outdoors & Recreation                    City
# 1526           Travel & Transport                   Hotel
# 1559        Outdoors & Recreation        Pedestrian Plaza
# 1560           Travel & Transport                   Hotel
# 1561           Travel & Transport                   Hotel
# 1563           Travel & Transport           Metro Station
# 1608        Outdoors & Recreation                  Garden
# 1628  Professional & Other Places     Monument / Landmark
# 1629               Shop & Service                    Mall
# 1633               Shop & Service       Electronics Store
# 1950           Travel & Transport           Train Station
# 2287               Shop & Service                    Mall
# 2353           Travel & Transport                   Hotel
# 3523               Shop & Service                    Mall
# 3532               Nightlife Spot               Nightclub
# 3577               Shop & Service       Electronics Store
# 3588        Outdoors & Recreation          Scenic Lookout
# 3590               Nightlife Spot                  Lounge
# 3665               Shop & Service                    Mall
# 3687  Professional & Other Places                Building
# 9010               Nightlife Spot                 Brewery
# 9037               Nightlife Spot                  Lounge
# 9139  Professional & Other Places         Buddhist Temple
# 9141           Travel & Transport                   Hotel
# 9238               Shop & Service                    Mall
#
#                                             name         lon        lat  \
# 187                                  IKEA | 宜家家居  121.429331  31.180020
# 287                                       港汇恒隆广场  121.432872  31.196687
# 288                             美罗城 | Metro City  121.435103  31.195265
# 539                      凯德龙之梦 | Cloud Nine Mall  121.411822  31.220692
# 718                           田子坊 | Tian Zi Fang  121.463985  31.210012
# 767                                上海 | Shanghai  121.464300  31.223869
# 1526            The Westin Bund Center, Shanghai  121.482441  31.234441
# 1559     南京路步行街 | Nanjing Road Pedestrian Street  121.476281  31.238050
# 1560                  新世界丽笙酒店 Radisson Blu Hotel  121.468428  31.236737
# 718      -1    -1.0                              food,entertaimant;亚文化
# 767      -1    -1.0  2010 world expo;jing an temple;shanghai;so gre...
# 1526     -1     8.4                         five star hotel, expensive
# 1559     -1     7.9                                                NaN
# 1560     -1     8.1                                                NaN
# 1561     -1     8.6  hotel;le royal meridien;le royal meridien shan...
# 1563     -1    -1.0  cbd;metro;metro line 1;metro line 2;metro line...
# 1608     -1     8.3         gardens;lakes;rocks;tourists;xiao long bao
# 1628     -1     8.2                           shanghai;tower;towner;tv
# 1629     -1     7.0  bellagio;burger king;ck jeans;crocs;element fr...
# 1633     -1     8.5  airport express;airport extreme;headphone;imac...
# 1950     -1     5.3  china railway high-speed;crh;harmony;railway;s...
# 2287     -1     6.5          department store;j's;mall;retail;shopping
# 2353     -1     8.2                                                NaN
# 3523     -1     7.6  charles & keith;gym;la senza;malaysian food;ma...
# 3532      3     8.1                                                NaN
# 3577     -1     8.0  airport express;airport extreme;headphone;imac...
# 3588     -1     9.5                                          frat boys
# 3590      3     8.9  best house music in shanghai;best shanghai vie...
# 3665     -1     8.3                                        luxury;mall
# 3687     -1     8.9  corporation;office;swfc;上海ヒルズ;上海ワールドフィナンシャルセンタ...
# 9010     -1     7.4                                                NaN
# 9037     -1     6.7                                                NaN
# 9139     -1     7.9                                             temple
# 9141     -1     7.7  american cuisine;bakery;conferences & events;f...
# 9238     -1     8.5                                                NaN
#
#       photoCount                                        description  CateValue
# 187          519                                                NaN          9
# 287          383  港汇恒隆广场（港汇广场66），坐落于华山路，虹桥路侧交界处，地铁一号线徐家汇站上盖，俯瞰上海...          9
# 288          207                                                NaN          9
# 539          248                                                NaN          9
# 718         1449                                                NaN          6
# 767         8195                                                NaN          6
# 1526         643                                                NaN         10
# 1559        1797                                                NaN          6
# 1560         501       Located at the zero centre point of Shanghai         10
# 1561         845  Located in the heart of Shanghai along the fam...         10
# 1563         257                                                NaN         10
# 1608        2232                                                NaN          6
# 1628        1916                                                NaN          7
# 1629         544  http://www.facebook.com/superbrandmall\nhttp:/...          9
# 1633         860                                                NaN          9
# 1950         713                                                NaN         10
# 2287         280                                                NaN          9
# 2353         381  Follow us on Foursquare at http://www.foursqua...         10
# 3523         259                                                NaN          9
# 3532        1125                                                NaN          5
# 3577         872                                                NaN          9
# 3588        4221                                                NaN          6
# 3590        1069  Bar Rouge is Shanghai Nightlife institution fo...          5
# 3665         738                                                NaN          9
# 3687        1444                                                NaN          7
# 9010         522                                                NaN          5
# 9037         267                                                NaN          5
# 9139        1212                                                NaN          7
# 9141         298                                                NaN         10
# 9238         575                                                NaN          9

# %%
cluster1.groupby('genCategory').agg({'CateValue': 'count',
                                  'users': 'mean',
                                  'checkIns': 'mean'})
# Out:
#                              CateValue      checkIns        users
# genCategory
# Nightlife Spot                       4   7942.250000  3375.000000
# Outdoors & Recreation                5  14180.200000  7574.800000
# Professional & Other Places          3   7644.666667  4671.666667
# Shop & Service                      11   8505.818182  3299.545455
# Travel & Transport                   7   8998.285714  3102.142857

# %%
cluster2 = data3[(data3.users < 2000) & (data3.checkIns < 5000)]
cluster2.shape
# Out:
# (1025, 20)

# %%
cluster2.describe()
# Out:
#                lon          lat     checkIns         tips        users  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean    121.456932    31.222400  1062.024390    14.848780   457.869268
# std       0.029496     0.019461   890.965128    16.537763   366.212568
# min     121.384037    31.171116   120.000000     0.000000   100.000000
# 25%     121.440039    31.210721   404.000000     4.000000   183.000000
# 50%     121.451329    31.221972   785.000000     9.000000   332.000000
# 75%     121.475128    31.233093  1412.000000    19.000000   596.000000
# max     121.547499    31.316129  4757.000000   152.000000  1986.000000
#
#         verified        price       rating   photoCount   CateValue
# count       1025  1025.000000  1025.000000  1025.000000  988.000000
# mean   0.0760976    -0.965854     5.627902    87.558049    5.865385
# std     0.265284     0.347711     3.363328   104.922771    2.619600
# min        False    -1.000000    -1.000000     0.000000    1.000000
# 25%            0    -1.000000     5.700000    27.000000    4.000000
# 50%            0    -1.000000     6.800000    56.000000    5.000000
# 75%            0    -1.000000     7.800000   110.000000    9.000000
# max         True     3.000000     9.400000  1683.000000   10.000000

# %%
cluster2
# Out:
#                        genCategory                                  category  \
# 0               Travel & Transport                                     Hotel
# 91                  Shop & Service                                      Mall
# 92              Travel & Transport                             Metro Station
# 94                  Shop & Service                                      Mall
# 100                           Food                       American Restaurant
# 125                 Shop & Service                        Miscellaneous Shop
# 140             Travel & Transport                                     Hotel
# 141                           Food                               Coffee Shop
# 142                      Residence  Residential Building (Apartment / Condo)
# 145             Travel & Transport                                     Hotel
# 147                           Food                          Tapas Restaurant
# 151    Professional & Other Places                                    Office
# 152             Travel & Transport                                     Hotel
# 153             Travel & Transport                                     Hotel
# 154                 Shop & Service                          Department Store
# 156          Outdoors & Recreation                                      Park
# 158             Travel & Transport                             Metro Station
# 159    Professional & Other Places                                  Building
# 161                           Food                       American Restaurant
# 164                           Food                               Coffee Shop
# 165                 Shop & Service                                      Mall
# 166    Professional & Other Places                                  Building
# 169          Outdoors & Recreation                          Sculpture Garden
# 170                           Food                         French Restaurant
# 171                           Food                               Coffee Shop
# 172                 Shop & Service                                      Mall
# 173           Arts & Entertainment                               Art Gallery
# 174             Travel & Transport                             Metro Station
# 175                           Food                        Chinese Restaurant
# 176                 Nightlife Spot                                       Bar
# ...                            ...                                       ...
# 9245   Professional & Other Places                                    Office
# 9247          Arts & Entertainment                                 Multiplex
# 9249                          Food                              Noodle House
# 9250                Shop & Service                    Furniture / Home Store
# 9251                          Food                       American Restaurant
# 9253                          Food                                      Café
# 9254                          Food                          Asian Restaurant
# 9255   Professional & Other Places                                  Building
# 9257         Outdoors & Recreation                                      Park
# 9261                          Food                               Coffee Shop
# 9263                          Food                        Chinese Restaurant
# 9264                          Food                              Noodle House
# 9269   Professional & Other Places                                  Building
# 9270                          Food                        Chinese Restaurant
# 9272                          Food                                 Gastropub
# 9275                          Food                                Steakhouse
# 9414          Arts & Entertainment                     General Entertainment
# 9444                          Food                          Asian Restaurant
# 9495   Professional & Other Places                           Coworking Space
# 9495   4f603517e4b0d13cc53540c0  China_Shanghai  2015.11.09 09:52:14
# 9587   4e282cb8d4c0e361d9db1e1d  China_Shanghai  2015.11.09 09:53:26
# 9589   4ce239fa7e2e236af39a941b  China_Shanghai  2015.11.09 09:53:26
# 9651   4da870c54b22e9f40e04e1d4  China_Shanghai  2015.11.09 09:54:14
# 9688   4b0588c4f964a52019d922e3  China_Shanghai  2015.11.09 09:55:18
# 9696   4e2510cfb0fbf642a8fb920e  China_Shanghai  2015.11.09 09:55:19
# 9724   4cab1fd6a6e08cfab1a8a294  China_Shanghai  2015.11.09 09:55:23
# 9789   4c77aa985cd6b1f71da33f94  China_Shanghai  2015.11.09 09:56:32
# 9831   4de9c4e088774880e30b1eea  China_Shanghai  2015.11.09 09:57:39
# 9936   4cd51cbb886cb60c76168289  China_Shanghai  2015.11.09 10:00:14
# 9937   4bded2c00ee3a59389f231b0  China_Shanghai  2015.11.09 10:00:14
# 10054  4b93604bf964a520ec4134e3  China_Shanghai  2015.11.09 10:02:34
#
#       verified  price  rating  \
# 0        False     -1    -1.0
# 91       False     -1     5.5
# 92       False     -1    -1.0
# 94       False     -1     5.4
# 100      False     -1     5.5
# 125      False     -1    -1.0
# 140       True     -1     7.5
# 141      False     -1     6.2
# 142      False     -1    -1.0
# 145      False     -1    -1.0
# 147      False     -1     6.6
# 151      False     -1    -1.0
# 152       True     -1     5.9
# 153       True     -1     6.3
# 154      False     -1     6.9
# 156      False     -1     6.4
# 158      False     -1    -1.0
# 159      False     -1    -1.0
# 161      False     -1     7.5
# 164      False     -1     6.4
# 165      False     -1     5.5
# 166      False     -1    -1.0
# 169      False     -1     8.8
# 170      False     -1     8.4
# 171      False     -1     6.4
# 172      False     -1     6.1
# 173      False     -1     7.3
# 174      False     -1    -1.0
# 175      False     -1     6.6
# 176      False     -1     7.8
# ...        ...    ...     ...
# 9245     False     -1    -1.0
# 9247     False     -1     8.7
# 9249     False     -1     8.0
# 9250     False     -1     8.2
# 9251     False     -1     7.3
# 9253     False     -1     6.5
# 9254     False     -1     7.2
# 9255     False     -1    -1.0
# 9257     False     -1     6.1
# 9261     False     -1     6.9
# 9263     False     -1     6.3
# 9264     False     -1     7.1
# 9269     False     -1    -1.0
# 9270     False     -1     6.3
# 9272     False     -1     5.5
# 9275     False     -1     7.1
# 9414     False     -1    -1.0
# 9444     False     -1     8.6
# 9495     False     -1    -1.0
# 9587     False     -1     7.9
# 9589     False     -1    -1.0
# 9651      True     -1     6.8
# 9688     False     -1     6.0
# 9696     False     -1    -1.0
# 9724     False     -1     5.8
# 9789     False     -1    -1.0
# 9831      True     -1     7.6
# 9936     False     -1    -1.0
# 9937     False     -1     7.7
# 10054    False     -1     8.0
#
#                                                     tags  photoCount  \
# 0                                                    NaN          23
# 91                                                   NaN          54
# 92     metro line 3;metro line 4;metro line 9;metro s...          47
# 94                                                   NaN          15
# 100                                                  NaN          24
# 125                                                  NaN           8
# 140     hhonors;hilton;hongqiao;hotel;shanghai;希尔顿;希尔顿酒店         135
# 141                              near huangjincheng road         121
# 142                                                  NaN           0
# 145                                                  NaN          27
# 147                                      chorizo;spanish          53
# 151                                                 蛋卷工坊         134
# 152                              hotel;sheraton;starwood         216
# 153                                                  NaN         143
# 154                                                  NaN         200
# 156                                                  NaN          95
# 158                                                  NaN          17
# 159                                                  NaN          69
# 161                                                  NaN         129
# 164                                                  NaN          12
# 165                                    business building          17
# 166                                                  NaN          90
# 169    ad agencies;beca cafe;coffee beans;gallery;max...         264
# 170                                                  NaN          44
# 171                                                  NaN          60
# 172                                                  NaN          14
# 173                        art, museum, shanghai;gallery         108
# 174    metro line 10;metro line 3;metro line 4;metro ...          51
# 175                                                  NaN          48
# 176                                                  NaN          18
# ...                                                  ...         ...
# 9245                                                 NaN          24
# 9247                                                 NaN          45
# 9249                                                 NaN          75
# 9250                                                 NaN          33
# 9251                                outdoor terrace;wifi         173
# 9253                                                 NaN          63
# 9254                                                 NaN          12
# 9255                                                 NaN          84
# 9257                                            dog runs          57
# 9261                                                 NaN          29
# 9263                                                 NaN          31
# 9264                                                 NaN          31
# 9269                                                 NaN          51
# 9270                                                 NaN           9
# 9272                                                 NaN          30
# 9275                                                 NaN          46
# 9414                                                 你懂的          10
# 9444                                                 NaN          35
# 9495                                                 NaN          53
# 9587                                                 NaN          23
# 9589                                                 NaN          22
# 9651                                                 NaN          21
# 9688                                                 NaN          28
# 9696                                                 NaN          14
# 9724                         café;coffee;cupcake;dessert          31
# 9789                                                 NaN          15
# 9831                                                 NaN          98
# 9936                                                 NaN           4
# 9937                                                 NaN           8
# 10054        camera;xingguang;上海星光摄影器材城;星光;星光摄影器材城;星光摄影城          42
#
#                                              description  CateValue
# 0                                                    NaN         10
# 91                                                   NaN          9
# 92                                                   NaN         10
# 94                                                   NaN          9
# 100                                                  NaN          4
# 125                                                  NaN          9
# 140    Situated in the heart of Hongqiao business dis...         10
# 141                                                  NaN          4
# 142                                                  NaN          8
# 145                                                  NaN         10
# 147                                                  NaN          4
# 151                                                  NaN          7
# 152                                                  NaN         10
# 153                                                  NaN         10
# 154                                                  NaN          9
# 156                                                  NaN          6
# 158                                                  NaN         10
# 159                                                  NaN          7
# 161                                                  NaN          4
# 164                                                  NaN          4
# 165                                                  NaN          9
# 166                                                  NaN          7
# 169                                                  NaN          6
# 170                                                  NaN          4
# 171                                                  NaN          4
# 172                                                  NaN          9
# 173                                                  NaN          1
# 174                                                  NaN         10
# 175                                                  NaN          4
# 176                                                  NaN          5
# ...                                                  ...        ...
# 9245                                                 NaN          7
# 9247                                                 NaN          1
# 9249                                                 NaN          4
# 9250                                                 NaN          9
# 9251                                                 NaN          4
# 9253                                                 NaN          4
# 9254                                                 NaN          4
# 9255                                                 NaN          7
# 9257                                                 NaN          6
# 9261                                                 NaN          4
# 9263                                                 NaN          4
# 9264                                                 NaN          4
# 9269                                                 NaN          7
# 9270                                                 NaN          4
# 9272                                                 NaN          4
# 9275                                                 NaN          4
# 9414                                                 NaN          1
# 9444                                                 NaN          4
# 9495                                                 NaN          7
# 9587                                                 NaN          4
# 9589                                                 NaN          7
# 9651   Holiday Inn hotels provide friendly service an...         10
# 9688                                                 NaN          9
# 9696                                                 NaN          4
# 9724                                                 NaN          4
# 9789                                                 NaN          6
# 9831                                                 NaN         10
# 9936                                                 NaN         10
# 9937                                                 NaN         10
# 10054                                                NaN          9
#
# [1025 rows x 20 columns]

# %%
cluster2.groupby('genCategory').agg({'CateValue': 'count',
                                  'users': 'mean',
                                  'checkIns': 'mean'})
# Out:
#                              CateValue     checkIns       users
# genCategory
# Arts & Entertainment                47   886.446809  502.468085
# College & University                12  1727.666667  394.750000
# Food                               409   855.317848  421.625917
# Nightlife Spot                     114  1321.780702  580.517544
# Outdoors & Recreation               48  1321.375000  570.187500
# Professional & Other Places         62  1040.016129  388.016129
# Residence                           12  1367.250000  164.750000
# Shop & Service                     140  1107.442857  408.528571
# Travel & Transport                 144  1310.736111  497.375000

# %%
trainlog = np.log10(train)
trainlog.head()
# Out:
#               users  checkIns
# CateValue
# 10         2.133539  2.336460
# 9          2.711807  3.236789
# 10         2.778874  3.423574
# 9          2.201397  2.507856
# 4          2.029384  2.201397

# %%
est_prob3=KMeans(n_clusters=10,n_init=100)
est_prob3.fit(trainlog)
labels=est_prob3.labels_
plt.figure(figsize=(8,8))
plt.scatter(trainlog.users,trainlog.checkIns,s=40,c=labels.astype(np.float),lw=0)
plt.xlabel('users', fontsize = 15)
plt.ylabel('checkIns', fontsize = 15)
plt.grid()

# %%
# start with a list of empty silhouette values
s = [0]*10
# select the best k
for i in range(0,10):
    est=KMeans(n_clusters=i+2,n_init=100)
    est.fit(trainlog)
    s[i]=silhouette_score(trainlog, est.labels_)
    print('{0} clusters: {1}'.format(i+2,s[i]))
j=np.argmax(s) # select best k value (max avg silhouette value)    
est=KMeans(n_clusters=j+2,n_init=100)
est.fit(trainlog)
labels=est.labels_
print('Best for {0} clusters: {1}\n'.format(j+2,silhouette_score(trainlog, labels)))
# Out:
# 2 clusters: 0.519163709095
# 3 clusters: 0.464390553535
# 4 clusters: 0.43260960372
# 5 clusters: 0.408730518294
# 6 clusters: 0.420712482109
# 7 clusters: 0.419393372612
# 8 clusters: 0.380075034582
# 9 clusters: 0.381080451575
# 10 clusters: 0.365203284349
# 11 clusters: 0.372795206063
# Best for 2 clusters: 0.519163709095

# %%
plt.figure()
plt.bar(range(2,12),s)
plt.xlabel('k')
plt.ylabel('S')
plt.title('Avg Silhouette vs k')

# %%
plt.figure(figsize=(8,8))
plt.scatter (trainlog.users,trainlog.checkIns,s=40,c=labels.astype(np.float),lw=0)

# %%
cluster3 = trainlog[(trainlog['users'] >= 2.8) & (trainlog['checkIns'] >= 3)]

# %%
cluster3.describe()
# Out:
#             users    checkIns
# count  281.000000  281.000000
# mean     3.068230    3.405854
# std      0.230815    0.265031
# min      2.801404    3.005609
# 25%      2.900913    3.214314
# 50%      2.996074    3.351410
# 75%      3.177825    3.553155
# max      4.001388    4.366834
